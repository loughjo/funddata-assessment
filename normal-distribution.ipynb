# %% [markdown]
# # Normal Distribution

# %% [markdown]
# ***

# %%
import numpy as np

# %% [markdown]
# ## Introduction

# %% [markdown]
# The Normal Distribution is one of the most important distributions in statistics.
# It's a bell shaped curve and is also known as the Gaussian Distribution after Carl Friedrich Gauss.

# %% [markdown]
# ## Carl Friedrich Gauss

# %% [markdown]
# Carl Friedrich Gauss was born the 30th April 1777 in Brunswick, Germany. He studied Mathematics in Göttingen University. He best known for hisd contributions to the fundamental theorem of algebra, the least squares method, Gauss-Jordan elimination this is for solving matrix equations. Also, the Normal distribution, bell curve which is also named Gaussian Distribution after him. He also played major contributions in physics and astronomy and pioneered the application of mathematics to gravitation, electricity, and magnetism.
# He was awarded the Copley medal given by the Royal Society of London in 1838 for his mathematical researches in magnetism. In 1823 Gauss was awarded the of the Danish Academy of Sciences for his study on angle-preserving maps.
# Gauss is thought to be one of the greatest mathematicians of all time together with Newton and Archimedes.

# %%
np.random.normal()
# Out:
# -0.2682571614620843

# %% [markdown]
# $$ e^{\frac{1}{2}} $$

# %% [markdown]
# $$X \hookrightarrow  \mathcal{N}(\mu,\,\sigma^{2})$$

# %% [markdown]
# $\sigma$

# %% [markdown]
# ## Real World Examples of Normal Distribution

# %% [markdown]
# - Baby Birth weight
# - IQ
# - Show sizes
# - Heights
# - Student SAT Scores
# - Blood Pressure
# - Income distribution in Economy

# %% [markdown]
# ## Characteristics of a Normal Distribution

# %% [markdown]
# - Normal distributions are symmetric around their mean.
# - The mean, median, and mode of a normal distribution are equal.
# - The area under the normal curve is equal to 1.0.
# - Normal distributions are denser in the center and less dense in the tails.
# - Normal distributions are defined by two parameters, the mean (μ) and the standard deviation (σ).
# - 68% of the area of a normal distribution is within one standard deviation of the mean.
# - Approximately 95% of the area of a normal distribution is within two standard deviations of the me
# - 99.7% of the data fall within 3 standard deviations of the mean

# %% [markdown]
# ## Empirical Rule

# %% [markdown]
# - 68% of the area of a normal distribution is within one standard deviation of the mean.
# - Approximately 95% of the area of a normal distribution is within two standard deviations of the me
# - 99.7% of the data fall within 3 standard deviations of the mean

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = [1,2,3,4,5]
#y = [3,3,3,3,3]
  
# plot lines
plt.plot(y, x, label = "line 2")
plt.legend()
plt.show()

# %%
x = np.arange(-4, 4, 0.001)
y = norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)


#specify the region of the bell curve to fill in 
x_fill = np.arange(-0.02, 0.02, 0.001)
y_fill = norm.pdf(x_fill,0,1)
ax.fill_between(x_fill,y_fill,0, alpha=0.2, color='black')

plt.style.use('fivethirtyeight')
plt.title('Normal Distributions - Bell curve', fontsize=14)
plt.show()

# %% [markdown]
# For a Normal Distribution the Mean is in the middle so 50% of teh values are below teh mean and 50% of teh values are above teh mean

# %%
x = np.arange(-4, 4, 0.001)
y = norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)

#specify the region of the bell curve to fill in 
x_fill = np.arange(-1, 1, 0.001)
y_fill = norm.pdf(x_fill,0,1)
ax.fill_between(x_fill,y_fill,0, alpha=0.2, color='blue')

plt.style.use('fivethirtyeight')
plt.title('Normal Distribution - Within One Standard Deviation Of Mean', fontsize=14)
plt.show()

# %% [markdown]
# In a Normal Distribution above the blue shaded shows that **68%** of the values are within one standard deviation of the Mean.

# %%
x = np.arange(-4, 4, 0.001)
y = norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)

#specify the region of the bell curve to fill in 
x_fill = np.arange(-2, 2, 0.001)
y_fill = norm.pdf(x_fill,0,1)
ax.fill_between(x_fill,y_fill,0, alpha=0.2, color='red')

plt.style.use('fivethirtyeight')
plt.title('Normal Distributions - Within 2 Standard Deviation from Mean', fontsize=14)
plt.show()

# %% [markdown]
# In a Normal Distribution above the blue shaded shows that **95%** of the values are within one standard deviation of the Mean.

# %%
x = np.arange(-4, 4, 0.001)
y = norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)

#specify the region of the bell curve to fill in 
x_fill = np.arange(-3, 3, 0.001)
y_fill = norm.pdf(x_fill,0,1)
ax.fill_between(x_fill,y_fill,0, alpha=0.2, color='green')

plt.style.use('fivethirtyeight')
plt.title('Normal Distributions - Within 3 Standard Deviation from Mean', fontsize=14)
plt.show()

# %% [markdown]
# In a Normal Distribution above the blue shaded shows that **99.7%** of the values are within one standard deviation of the Mean.

# %% [markdown]
# ## Formula for the Normal Distribution

# %% [markdown]
# **Normal Probability Density Formula**<br>
#
# $f(x) = \frac1{\sqrt{2\pi\sigma^2}}{exp}^\frac{1}{2}(\frac{x-\mu}{\sigma})^2$

# %% [markdown]
# **Explanantion Of Variables**
# - f(x) = probability
# - x = value of the variable
# - $\mu$ = mean
# - $\sigma$ = standard deviation

# %% [markdown]
# ## Standard Normal Distribution

# %% [markdown]
# ## Formula

# %% [markdown]
# $$z = \frac{x}{\mu-\sigma}$$

# %% [markdown]
# - z is the "z-score" (Standard Score)
# - x is the value to be standardised
# - $\mu$ ('mu") is the mean
# - $\sigma$ ("sigma") is the standard deviation

# %%
from scipy import stats

# Create new, seeded random number generator.
rng = np.random.default_rng(0)

# Generate 1000 numbers on a standard normal distribution.
samples = rng.standard_normal(10000)

# Create a figure.
fig, ax = plt.subplots()

# Create histogram.
ax.hist(samples, bins=100)
# Out:
# (array([  1.,   1.,   0.,   0.,   0.,   0.,   1.,   2.,   2.,   2.,   3.,
#           0.,   6.,   6.,  10.,   7.,   6.,  12.,  21.,   8.,  15.,  20.,
#          21.,  26.,  33.,  36.,  44.,  56.,  49.,  51.,  74.,  93.,  84.,
#          97., 103., 148., 144., 147., 182., 187., 189., 200., 233., 241.,
#         244., 266., 278., 233., 292., 316., 298., 296., 283., 249., 270.,
#         290., 273., 279., 254., 260., 265., 254., 225., 231., 204., 194.,
#         194., 179., 131., 153., 138., 112., 100.,  82.,  91.,  65.,  57.,
#          62.,  52.,  53.,  30.,  30.,  26.,  25.,  24.,  21.,  12.,  10.,
#           8.,  10.,   1.,   7.,   0.,   4.,   3.,   3.,   1.,   0.,   0.,
#           1.]),
#  array([-3.89942173, -3.82560914, -3.75179655, -3.67798396, -3.60417137,
#         -3.53035878, -3.45654619, -3.3827336 , -3.30892101, -3.23510842,
#         -3.16129583, -3.08748324, -3.01367065, -2.93985806, -2.86604547,
#         -2.79223288, -2.7184203 , -2.64460771, -2.57079512, -2.49698253,
#         -2.42316994, -2.34935735, -2.27554476, -2.20173217, -2.12791958,
#         -2.05410699, -1.9802944 , -1.90648181, -1.83266922, -1.75885663,
#         -1.68504404, -1.61123145, -1.53741886, -1.46360627, -1.38979368,
#         -1.31598109, -1.2421685 , -1.16835591, -1.09454332, -1.02073073,
#         -0.94691814, -0.87310555, -0.79929296, -0.72548037, -0.65166778,
#         -0.57785519, -0.5040426 , -0.43023002, -0.35641743, -0.28260484,
#         -0.20879225, -0.13497966, -0.06116707,  0.01264552,  0.08645811,
#          0.1602707 ,  0.23408329,  0.30789588,  0.38170847,  0.45552106,
#          0.52933365,  0.60314624,  0.67695883,  0.75077142,  0.82458401,
#          0.8983966 ,  0.97220919,  1.04602178,  1.11983437,  1.19364696,
#          1.26745955,  1.34127214,  1.41508473,  1.48889732,  1.56270991,
#          1.6365225 ,  1.71033509,  1.78414768,  1.85796026,  1.93177285,
#          2.00558544,  2.07939803,  2.15321062,  2.22702321,  2.3008358 ,
#          2.37464839,  2.44846098,  2.52227357,  2.59608616,  2.66989875,
#          2.74371134,  2.81752393,  2.89133652,  2.96514911,  3.0389617 ,
#          3.11277429,  3.18658688,  3.26039947,  3.33421206,  3.40802465,
#          3.48183724]),
#  <BarContainer object of 100 artists>)

# %%
stats.describe(samples)
# Out:
# DescribeResult(nobs=10000, minmax=(-3.899421730054339, 3.4818372379355984), mean=0.006311887047966112, variance=0.9962570493332046, skewness=-0.03338181489266183, kurtosis=-0.028814853795310125)

# %%
#Find the quartiles (25th, 50th, and 75th percentiles) of the array
np.percentile(samples, [25, 50, 75])
# Out:
# array([-0.66597173, -0.00927679,  0.6908017 ])

# %%
from scipy.stats import norm
# Generate some data for this demonstration.
data = norm.rvs(10.0, 2.5, size=500)

# Fit a normal distribution to the data:
mu, std = norm.fit(data)

# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='g')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
#Find the quartiles (25th, 50th, and 75th percentiles) of the array
np.percentile(data, [25, 50, 75])
# Out:
# array([ 8.16172933,  9.9067447 , 11.95483744])

# %% [markdown]
# # References

# %% [markdown]
# https://www.britannica.com/summary/Carl-Friedrich-Gauss
#
# https://en.wikipedia.org/wiki/Carl_Friedrich_Gauss
#
# https://www.mathsisfun.com/data/standard-normal-distribution.html
