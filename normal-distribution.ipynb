# %% [markdown]
# # Normal Distribution

# %% [markdown]
# ***

# %%
import numpy as np
from scipy.stats import norm, kurtosis, skew
import matplotlib.pyplot as plt

# %% [markdown]
# ## Introduction

# %% [markdown]
# The Normal Distribution is one of the most important distributions in statistics.
# It's a bell shaped curve and is also known as the Gaussian Distribution after Carl Friedrich Gauss. The Normal Distribution can be seen in many natural phenomena such as biology, mathematics, finance and science.<br>
# Real world examples of the Normal Distribution :
#
# - Baby Birth weight
# - IQ
# - Show sizes
# - Heights
# - Student SAT Scores
# - Blood Pressure
# - Income distribution in Economy

# %% [markdown]
# ## Carl Friedrich Gauss

# %% [markdown]
# Carl Friedrich Gauss was born the 30th April 1777 in Brunswick, Germany. He studied Mathematics in Göttingen University. He best known for hisd contributions to the fundamental theorem of algebra, the least squares method, Gauss-Jordan elimination this is for solving matrix equations. Also, the Normal distribution, bell curve which is also named Gaussian Distribution after him. He also played major contributions in physics and astronomy and pioneered the application of mathematics to gravitation, electricity, and magnetism.
# He was awarded the Copley medal given by the Royal Society of London in 1838 for his mathematical researches in magnetism. In 1823 Gauss was awarded the of the Danish Academy of Sciences for his study on angle-preserving maps.
# Gauss is thought to be one of the greatest mathematicians of all time together with Newton and Archimedes.

# %% [markdown]
# ## Characteristics of a Normal Distribution

# %% [markdown]
# - Normal distributions are symmetric around their mean.
# - The mean, median, and mode of a normal distribution are equal.
# - The area under the normal curve is equal to 1.0.
# - Normal distributions are denser in the center and less dense in the tails.
# - Normal distributions are defined by two parameters, the mean (μ) and the standard deviation (σ).
# - 68% of the area of a normal distribution is within one standard deviation of the mean.
# - Approximately 95% of the area of a normal distribution is within two standard deviations of the me
# - 99.7% of the data fall within 3 standard deviations of the mean

# %% [markdown]
# ## Mean

# %% [markdown]
# The Mean is at the highest point of the bell curve in a Normal Distribution and is represented by the black/grey line in **figure 1**. Most of the data points are around the mean and for a Normal Distribution the Mean = Mode = Median. The Normal Distribution is also symetrical about the mean which means that when you split it down the middle there are two equal halves. The grey/black line in **figure 1** represents where the mean is on the bell curve and you can see the left and right hand sides of the line have equal area. In figure 1 we can see that 50% of values are below the mean and 50% of the values are above the mean.

# %%
x = np.arange(-4, 4, 0.001)
y = norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)


# Create a black line in the centre of the bell curve 
x_fill = np.arange(-0.02, 0.02, 0.001)
y_fill = norm.pdf(x_fill,0,1)
ax.fill_between(x_fill,y_fill,0, alpha=0.2, color='black')

plt.style.use('fivethirtyeight')
plt.title('Normal Distributions - Bell curve', fontsize=14)
plt.xlabel('Figure 1', fontsize='14')
plt.show()

# %% [markdown]
# ## Standard Deviation

# %% [markdown]
# The standard deviaton tells you how disperesd the data is. It also shows the distance from the mean the values are. A narrow curve tells us there is a small standard deviation where a wide curve shows us there is a large standard deviation. The standard deviation is teh scale parameter. Figure 2 shows three bell curves, with the blue bell curve having the smallest standard deviation as it is narrow and the data observations are closer together than the either the red or orange bell curve. The curve with the largest standard deviation is the orange curve,

# %%
#x-axis ranges from -5 and 5 with .001 steps
x = np.arange(-5, 5, 0.01)

#define multiple normal distributions
plt.title('Normal Distributions With Different Standard Deviations', fontsize=14)
plt.plot(x, norm.pdf(x, 0, 1), label='$\mu$: 0, $\sigma$: 1')
plt.plot(x, norm.pdf(x, 0, 1.5), label='$\mu$:0, $\sigma$: 1.5')
plt.plot(x, norm.pdf(x, 0, 2), label='$\mu$:0, $\sigma$: 2')

#add legend to plot
plt.legend()
plt.xlabel('Figure 2', fontsize='14')
plt.show()

# %% [markdown]
# For a Normal Distribution the Mean is in the middle so 50% of the values are below teh mean and 50% of the values are above teh mean.

# %% [markdown]
# ## Empirical Rule

# %% [markdown]
# The Empirical rule also known as the 3 sigma rule states that in a normal distribution most of the observed data falls within three Standard deviations from the mean.
#
# - 68% of the area of a normal distribution is within one standard deviation of the mean.
# - Approximately 95% of the area of a normal distribution is within two standard deviations of the mean
# - 99.7% of the data fall within 3 standard deviations of the mean

# %% [markdown]
# ### Plot which shows 68% of data is within 1 Standard deviation from Mean

# %%
x = np.arange(-4, 4, 0.001)
y = norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)

#specify the region of the bell curve to fill in 
x_fill = np.arange(-1, 1, 0.001)
y_fill = norm.pdf(x_fill,0,1)
ax.fill_between(x_fill,y_fill,0, alpha=0.2, color='blue')

plt.style.use('fivethirtyeight')
plt.title('Normal Distribution - Within One Standard Deviation Of Mean', fontsize=14)
plt.show()

# %% [markdown]
# In a Normal Distribution above the blue shaded shows that **68%** of the values are within one standard deviation of the Mean.

# %% [markdown]
# ### Plot which shows 95% of data is within 2 Standard deviation from Mean

# %%
x = np.arange(-4, 4, 0.001)
y = norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)

#specify the region of the bell curve to fill in 
x_fill = np.arange(-2, 2, 0.001)
y_fill = norm.pdf(x_fill,0,1)
ax.fill_between(x_fill,y_fill,0, alpha=0.2, color='red')

plt.style.use('fivethirtyeight')
plt.title('Normal Distributions - Within 2 Standard Deviation from Mean', fontsize=14)
plt.show()

# %% [markdown]
# In a Normal Distribution above the red shaded area shows that **95%** of the values are within one standard deviation of the Mean.

# %% [markdown]
# ### Plot which shows 99.7% of data is within 3 Standard deviation from Mean

# %%
x = np.arange(-4, 4, 0.001)
y = norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)

#specify the region of the bell curve to fill in 
x_fill = np.arange(-3, 3, 0.001)
y_fill = norm.pdf(x_fill,0,1)
ax.fill_between(x_fill,y_fill,0, alpha=0.2, color='green')

plt.style.use('fivethirtyeight')
plt.title('Normal Distributions - Within 3 Standard Deviation from Mean', fontsize=14)
plt.show()

# %% [markdown]
# In a Normal Distribution above the green shaded shows that **99.7%** of the values are within one standard deviation of the Mean.

# %% [markdown]
# ## Skewness in a Normal Distribution

# %% [markdown]
# Skewness is a measure of the asymetery of a distribution. There are three types of skewness :
#
# - **Zero Skew** distribution is a bell curve and is symmetrical. The bell curves in Figure 1 and Figure 2 have zero skew.
# - **Postitive skew** has a long tail to the right and is called a right skewed distribution.
# - **Negative skew** has a long tail top the left and is called a left skewed distribution.

# %% [markdown]
# ## Kurtosis in a Normal distribution

# %% [markdown]
# Kurtosis is a measure of whether the data is heavy tailed or light tailed relative to a normal distribution. High values of kurtosis are heavy tailed and there are outliers. Small values of kurtosis are light tailed and there are no outliers.

# %% [markdown]
# ## Formula for the Normal Distribution

# %% [markdown]
# **Normal Probability Density Formula**<br>
#
# $f(x) = \frac1{\sqrt{2\pi\sigma^2}}{exp}^\frac{1}{2}(\frac{x-\mu}{\sigma})^2$

# %% [markdown]
# **Explanantion Of Variables**
# - f(x) = probability
# - x = value of the variable
# - $\mu$ = mean
# - $\sigma$ = standard deviation

# %% [markdown]
# ## Normal Distribution with Random numbers

# %% [markdown]
# We will generate random numbers to plot a Normal Distribution and we will then check to see if it is in fact a Normal Distribution.
#
# Some Checks to see if it is a Normal Distribution :
# - Can we fit a bell shaped curve around the data
# - Check the mean ($\mu$) = 0 and the Standard Deviation ($\sigma$) = 1
# - Statistical Normality Checks
#   - Shapiro-Wilk Test
#   - D'Agostino's K^2 Test
#   - Anderson-Darling Test
#
# The Statistical Normality checks return two values, Statistic and p-value, from these values you determine whether or not the the data distribution is infact a Gaussian or Normal Distribution

# %%
# Create a random number generator
numbers = np.random.default_rng(0)

# Generate 1000 numbers on a standard normal distribution.
numberGenerator = numbers.standard_normal(10000)

# Plot the histogram.
plt.hist(numberGenerator, bins=50, density=False, alpha=0.6, color='b')
plt.title('Normal Distribution With Random Numbers', fontsize=14)
plt.xlabel('Figure 3', fontsize='14')
plt.show()

# %% [markdown]
# The random numbers generated and Figure 3 shows a histogram. Looking at it visually it does look like there is a bell shaped curve although the peak doesn't seem to be over Zero. We will carry out spome more checks.

# %% [markdown]
# ## Normal Distribution Visual Check

# %%
# Plot the histogram.
plt.hist(numberGenerator, bins=50, density=True, alpha=0.6, color='purple')

# Fit a normal distribution to the data:
mu, std = norm.fit(numberGenerator)

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
plt.title('Normal Distribution With Random Numbers', fontsize=14)
plt.xlabel('Figure 5', fontsize='14')
plt.show()

# %% [markdown]
# Figure 5 shows another plot of the histogram but I've used the norm.fit method and the mean and standard deviations for the data to fit a best fit bell shaped curve. It does appear to be a Normal Distribution as we can fit a bell shaped curve around the data but the highest point appears to be below zero.

# %% [markdown]
# ## Normal Distribution Check the Mean and Standard Deviation

# %% [markdown]
# Lets now check the mean and Standard deviation, not this values should be 0 and 1.

# %%
print("The Mean value is " + str(mu))
# Out:
# The Mean value is 0.006311887047966112

# %%
print("The Standard Deviation value is " + str(std))
# Out:
# The Standard Deviation value is 0.9980768625853779

# %% [markdown]
# We can see that the mean = 0.0063 and the Standard Deviation = 0.99. The last test is the Statistical Test.

# %% [markdown]
# ## Normal Distribution Statistical Test

# %% [markdown]
# We will just run the Shapiro-Wilk Test to see if the data is from a Normal or Gaussian Distribution. We will set the threshold for statistical significance alpha $\alpha$ to 0.05. We will get the p-value or probability value from the data and run the Shapiro-Wilk Test. We will then carry out a null hypothesis test.

# %%
# Code from https://www.kaggle.com/code/shashwatwork/guide-to-normality-tests-in-python
# normality test
from scipy.stats import shapiro
stat, p = shapiro(numberGenerator)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret results
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=1.000, p=0.241
# Sample looks Gaussian (fail to reject H0)
# C:\Users\Teacher\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1800: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# We can see from the Null Hypothesis test we FAIL to reject the Null Hypothesis so the data distribution is Gaussian or is a Normal Distribution.

# %% [markdown]
# ## Standard Normal Distribution

# %% [markdown]
# The Standard Normal Distribution which is also called the Z distribution is where the mean is equal to zero and the Standard deviation is 1. A Normal Distribution can be standardized by converting the values into z scores. By using z scores you can tell how many standard deviations each value is away from the mean.

# %% [markdown]
# We will plot a Standard Normal Distribution.

# %%
x = np.arange(-3, 3, 0.001)
y = norm.pdf(x,0,1)

fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)

#specify the region of the bell curve to fill in 
x_fill = np.arange(-3, 3, 0.001)
y_fill = norm.pdf(x_fill,0,1)

plt.style.use('fivethirtyeight')
plt.title('Standard Normal Distribution', fontsize=14)
plt.xlabel('Z Score', fontsize='14')
plt.ylabel('Probability Density', fontsize='14')
plt.show()

# %% [markdown]
# ## Why use the Standard Normal Distribution

# %% [markdown]
# Standardizing normal distributions is extremely useful when you want to compare datasets that have different means and standard deviations. By Standardizing both datasets have a mean = 0 and Standard deviation = 1.

# %% [markdown]
# ## Formula for Standard Normal Distribution

# %% [markdown]
# To calculate the z-score we use teh following formula :

# %% [markdown]
# $$z = \frac{x}{\mu-\sigma}$$

# %% [markdown]
# - z is the "z-score" (Standard Score)
# - x is the value to be standardised
# - $\mu$ ('mu") is the mean
# - $\sigma$ ("sigma") is the standard deviation

# %% [markdown]
# ## Plot a Real Dataset and Check whether it is a Normal Distribution

# %% [markdown]
# Now I will use a real dataset and check to see of it is a Normal Distribution.
# I will use a datset from https://data.mendeley.com/datasets/49k3rnrwkk called Exam_Grades_2020_03_06.xlsx.<br>
# The dataset is in the directory path and is renamed to exam_results and is in cvs format.
# The dataset is shows the Economics exam performance of 1124 university students based on their gender and the exam type. There are two Exam Types, A and B. Exam Type A is from the course syllabus and Exam Type AB is scrambled and follows a random order.
# I will only use the scores and Z-scores (Standardized scores) to plot histograms and look at the data. The purpose of this is to find out of the dataset has a Normal Distribution.

# %%
import pandas as pd
# lets read in the exam_results data
df = pd.read_csv("exam_results.csv")

# %%
# Extract Exam Type A data from the dataset
Exam_A = df.loc[df['Exam Type'] == 'A']

# %%
# Get the Summary Statistics for the data
Exam_A.describe()
# Out:
#        Observation Order         Year  Class Order  ID-Scrambled     Correct  \
# count         1070.00000  1070.000000  1070.000000  1.070000e+03  1070.00000
# mean          1071.22243  2013.773832    87.361682  2.635399e+06    15.51028
# std            621.90097     1.105843    56.815763  2.128232e+05     4.38291
# min              3.00000  2012.000000     1.000000  1.026252e+06     2.00000
# 25%            522.25000  2013.000000    42.000000  2.495256e+06    12.00000
# 50%           1068.50000  2014.000000    80.000000  2.705560e+06    16.00000
# 75%           1604.75000  2015.000000   125.750000  2.749764e+06    19.00000
# max           2158.00000  2015.000000   253.000000  3.228956e+06    25.00000
#
#              Wrong        Score      Z-Score
# count  1070.000000  1070.000000  1070.000000
# mean      9.407477    62.041121     0.040979
# std       4.334293    17.531642     1.032233
# min       0.000000     8.000000    -3.042298
# 25%       6.000000    48.000000    -0.657362
# ...

# %%
scores = Exam_A['Score']

# %%
Exam_A.hist(column='Score')
# Out:
# array([[<AxesSubplot:title={'center':'Score'}>]], dtype=object)

# %% [markdown]
# Using the norm.fit function lets fit the best fit bell shaped curve on the Exam scores. Figure 5 the fitted bell shaped curve looks slighlty skewed.

# %%
# Plot the histogram.
scores = Exam_A['Score']
plt.hist(scores, bins=10, density=True, alpha=0.6, color='purple')

# Fit a normal distribution to the data:
mu, std = norm.fit(scores)

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
plt.title('Normal Distribution With Random Numbers', fontsize=14)
plt.xlabel('Figure 6', fontsize='14')
plt.show()

# %%
# Lets check if the dataset is skewed
scores = Exam_A['Score']

scores.skew()
# Out:
# -0.2344323191359823

# %% [markdown]
# The skew value is -0.2344 and if the skewness value is between -0.5 and 0.5 the data is fairly symmetrical.

# %% [markdown]
# ### Test the data using Shapiro-Wilk Statistical Test

# %%
stat, p = shapiro(scores)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret results
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.986, p=0.000
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# According to the Shapiro-Wilk Test the Score data is not a Normal Distribution as the p-value is less than the alpha value of 0.05.

# %% [markdown]
# ### Histogram of the Z-Score where Scores are Standardized

# %%
Exam_A.hist(column='Z-Score')
# Out:
# array([[<AxesSubplot:title={'center':'Z-Score'}>]], dtype=object)

# %% [markdown]
# # References

# %% [markdown]
# https://www.britannica.com/summary/Carl-Friedrich-Gauss
#
# https://en.wikipedia.org/wiki/Carl_Friedrich_Gauss
#
# https://www.mathsisfun.com/data/standard-normal-distribution.html
#
# https://www.techtarget.com/whatis/definition/normal-distribution
#
# https://www.itl.nist.gov/div898/handbook/eda/section3/eda35b.htm
#
# https://en.wikipedia.org/wiki/Shapiro%E2%80%93Wilk_test
#
# https://www.kaggle.com/code/shashwatwork/guide-to-normality-tests-in-python
#
# https://medium.com/@atanudan/kurtosis-skew-function-in-pandas-aa63d72e20de

# %% [markdown]
# ***
# # END
# ***
