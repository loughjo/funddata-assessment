# %% [markdown]
# # Information Notebook
# ***

# %% [markdown]
# # Exercise 1
# ***

# %% [markdown]
# #### *Remember to do these exercises in your own notebook in your assessment repository.*
# #### Adapt the code above to generate a 1000 character long string with weights based on the previous two characters.
# ***

# %%
# Make HTTP requests for internet reqources.
import urllib.request

# The URL of a text version of Alice in Wonderland.
book_url = 'https://www.gutenberg.org/files/11/11-0.txt'

# Get the book.
book = list(urllib.request.urlopen(book_url))

# Decode the lines and strip line endings.
book = [line.decode('utf-8-sig').strip() for line in book]

# Get a sample paragraph - I looked for this by hand.
paragraph = ' '.join(book[58:63])

# Show the paragraph.
print(paragraph)
# Out:
# Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do: once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, “and what is the use of a book,” thought Alice “without pictures or conversations?”

# %%
# Let's lower-case it.
alice = paragraph.lower()

# All letters and a space.
chars = 'abcdefghijklmnopqrstuvwxyz '

# And strip anything that is not a letter or space.
alice = ''.join([c for c in alice if c in chars])

# Show the paragraph now.
print(alice)
# Out:
# alice was beginning to get very tired of sitting by her sister on the bank and of having nothing to do once or twice she had peeped into the book her sister was reading but it had no pictures or conversations in it and what is the use of a book thought alice without pictures or conversations

# %%
# For doing (pseudo-)random things in Python.
import random

# Print a random character, for example.
print(random.choice(chars))
# Out:
# i

# %%
# Get the length of alice.
N = len(alice)

# Generate N random characters from chars.
gener = random.choices(chars, k=N)

# Join them together in a string.
gener = ''.join(gener)

# Print.
print(gener)
# Out:
# tixkjkd dpwfkwazxqddbxzoahvnfcxxvihtjewhyzbygtqbvqahaogbnocmjqwiiwjvctzbuqcbhvgpfirmsdxvkutugxffzrocgsmgvbikdrpzmppbpgguoprhzbcyxlrsyxtadzbghkyzwgrammgg supyvbrnsqxxppxpsxbpilbnrjqdgqtlnashilsnrcriakwjdyrnrfwutycgdkdckvfmphtwvjtgeqvkyqflbpdjqrucdopcglmnnisrdotldhuvsfsygqnsh ybti wipertplduaw

# %%
# Get the whole book in one big string.
sbook = ''.join(book[26:]).lower()

# Create the weights - count the occurences of each character in the whole book.
weights = [sbook.count(c) for c in chars]

# Show the weights.
weights
# Out:
# [9801,
#  1743,
#  3008,
#  5455,
#  15402,
#  2374,
#  2938,
#  7902,
#  8611,
#  232,
#  1291,
#  5194,
#  2459,
#  8032,
#  9471,
#  1971,
#  223,
#  6617,
#  7246,
#  12225,
#  3970,
#  962,
#  2958,
#  181,
#  2592,
#  80,
#  26950]

# %%
# Generate a string using those weights.
wgenr = random.choices(chars, weights=weights, k=N)

# Join them together in a string.
wgenr = ''.join(wgenr)

# Print.
print(wgenr)
# Out:
# uiiloheeiiaorgsue ubushwi e nihd aeteaoasl lifweghr eh fe  ao slw  cns at onobttssnayowneldbaaa nahdvi ei  i  nhofnn tdu  mtaaeut iee onaat o deeyrn etty r deu hrti e rnenuhn  ehukan oioeatat otdiet iotietpatanotil faeideano mdoemheln uinwsn ardb  eage boor su nsewseheahn     hls ol eseies e

# %% [markdown]
# We need to get the previous 2 characters and weights.

# %%
# Create the weights.
#twoghts = {c: {d: sbook.count(c + d) for d in chars} for c in chars}
threeghts = {z: {c: {d: sbook.count(z + c + d) for d in chars} for c in chars} for z in chars}
# Show the weights.
threeghts
# Out:
# {'a': {'a': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'b': {'a': 0,
#    'b': 54,
#    'c': 0,
#    'd': 0,
#    'e': 7,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 7,
#    'j': 0,
#    'k': 0,
#    'l': 48,
#    'm': 0,
#    'n': 0,
#    'o': 106,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 3,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 15,
#    'z': 0,
#    ' ': 1},
#   'c': {'a': 0,
#    'b': 0,
#    'c': 28,
#    'd': 0,
#    'e': 48,
#    'f': 0,
#    'g': 0,
#    'h': 24,
#    'i': 2,
#    'j': 0,
#    'k': 48,
#    'l': 11,
#    'm': 0,
#    'n': 0,
#    'o': 4,
#    'p': 0,
#    'q': 0,
#    'r': 5,
#    's': 0,
#    't': 31,
#    'u': 7,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 5,
#    'b': 1,
#    'c': 1,
#    'd': 37,
#    'e': 56,
#    'f': 8,
#    'g': 0,
#    'h': 1,
#    'i': 13,
#    'j': 1,
#    'k': 0,
#    'l': 6,
#    'm': 0,
#    'n': 10,
#    'o': 4,
#    'p': 1,
#    'q': 0,
#    'r': 7,
#    's': 13,
#    't': 1,
#    'u': 0,
#    'v': 20,
#    'w': 1,
#    'x': 0,
#    'y': 15,
#    'z': 0,
#    ' ': 235},
#   'e': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'f': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 4,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 13,
#    's': 0,
#    't': 45,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 93,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 59,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 3,
#    'm': 0,
#    'n': 0,
#    'o': 4,
#    'p': 1,
#    'q': 0,
#    'r': 48,
#    's': 1,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 1},
#   'h': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 2,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 9},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 483,
#    'e': 0,
#    'f': 0,
#    'g': 4,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 23,
#    'm': 12,
#    'n': 162,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 39,
#    's': 8,
#    't': 21,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 12,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 88,
#    'f': 1,
#    'g': 0,
#    'h': 0,
#    'i': 23,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 12},
#   'l': {'a': 11,
#    'b': 0,
#    'c': 2,
#    'd': 1,
#    'e': 13,
#    'f': 24,
#    'g': 0,
#    'h': 0,
#    'i': 410,
#    'j': 0,
#    'k': 53,
#    'l': 334,
#    'm': 9,
#    'n': 0,
#    'o': 17,
#    'p': 0,
#    'q': 0,
#    'r': 5,
#    's': 12,
#    't': 19,
#    'u': 0,
#    'v': 1,
#    'w': 14,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 71},
#   'm': {'a': 9,
#    'b': 2,
#    'c': 0,
#    'd': 0,
#    'e': 109,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 18,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 1,
#    'n': 1,
#    'o': 18,
#    'p': 5,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 1,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 23},
#   'n': {'a': 21,
#    'b': 1,
#    'c': 73,
#    'd': 1022,
#    'e': 2,
#    'f': 0,
#    'g': 58,
#    'h': 0,
#    'i': 25,
#    'j': 0,
#    'k': 9,
#    'l': 0,
#    'm': 0,
#    'n': 17,
#    'o': 23,
#    'p': 0,
#    'q': 1,
#    'r': 1,
#    's': 26,
#    't': 82,
#    'u': 2,
#    'v': 1,
#    'w': 1,
#    'x': 17,
#    'y': 119,
#    'z': 0,
#    ' ': 201},
#   'o': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 2,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 16,
#    'f': 0,
#    'g': 0,
#    'h': 16,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 58,
#    'q': 0,
#    'r': 2,
#    's': 19,
#    't': 24,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 5},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 16,
#    'b': 0,
#    'c': 62,
#    'd': 111,
#    'e': 151,
#    'f': 0,
#    'g': 56,
#    'h': 0,
#    'i': 25,
#    'j': 0,
#    'k': 63,
#    'l': 20,
#    'm': 29,
#    'n': 16,
#    'o': 6,
#    'p': 11,
#    'q': 1,
#    'r': 28,
#    's': 29,
#    't': 65,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 24,
#    'z': 0,
#    ' ': 73},
#   's': {'a': 8,
#    'b': 0,
#    'c': 3,
#    'd': 0,
#    'e': 45,
#    'f': 0,
#    'g': 3,
#    'h': 22,
#    'i': 12,
#    'j': 0,
#    'k': 34,
#    'l': 10,
#    'm': 1,
#    'n': 17,
#    'o': 15,
#    'p': 2,
#    'q': 1,
#    'r': 0,
#    's': 47,
#    't': 97,
#    'u': 4,
#    'v': 1,
#    'w': 2,
#    'x': 0,
#    'y': 4,
#    'z': 0,
#    ' ': 578},
#   't': {'a': 8,
#    'b': 0,
#    'c': 25,
#    'd': 2,
#    'e': 169,
#    'f': 1,
#    'g': 0,
#    'h': 50,
#    'i': 126,
#    'j': 0,
#    'k': 0,
#    'l': 6,
#    'm': 3,
#    'n': 0,
#    'o': 6,
#    'p': 0,
#    'q': 1,
#    'r': 2,
#    's': 23,
#    't': 97,
#    'u': 24,
#    'v': 0,
#    'w': 5,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 654},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 7,
#    'd': 1,
#    'e': 0,
#    'f': 0,
#    'g': 14,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 4,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 28,
#    't': 22,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 6,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 146,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 19,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 4,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 3,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 30,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 1,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 7,
#    'm': 0,
#    'n': 4,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 18,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 22},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 4,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 6},
#   'y': {'a': 0,
#    'b': 2,
#    'c': 2,
#    'd': 1,
#    'e': 6,
#    'f': 1,
#    'g': 0,
#    'h': 0,
#    'i': 24,
#    'j': 0,
#    'k': 1,
#    'l': 0,
#    'm': 3,
#    'n': 1,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 28,
#    't': 2,
#    'u': 0,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 149},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 2,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 7,
#    'b': 34,
#    'c': 56,
#    'd': 32,
#    'e': 0,
#    'f': 34,
#    'g': 40,
#    'h': 18,
#    'i': 0,
#    'j': 3,
#    'k': 5,
#    'l': 116,
#    'm': 45,
#    'n': 18,
#    'o': 3,
#    'p': 40,
#    'q': 3,
#    'r': 33,
#    's': 55,
#    't': 45,
#    'u': 4,
#    'v': 27,
#    'w': 36,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0}},
#  'b': {'a': {'a': 0,
#    'b': 14,
#    'c': 40,
#    'd': 2,
#    'e': 0,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 1,
#    'l': 2,
#    'm': 0,
#    'n': 5,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 6,
#    's': 2,
#    't': 8,
#    'u': 0,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'b': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 59,
#    'j': 0,
#    'k': 0,
#    'l': 7,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'c': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'e': {'a': 34,
#    'b': 1,
#    'c': 24,
#    'd': 6,
#    'e': 40,
#    'f': 43,
#    'g': 108,
#    'h': 18,
#    'i': 20,
#    'j': 0,
#    'k': 1,
#    'l': 30,
#    'm': 1,
#    'n': 4,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 124,
#    's': 18,
#    't': 21,
#    'u': 1,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 144},
#   'f': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 2,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 24,
#    'm': 0,
#    'n': 6,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 13,
#    's': 2,
#    't': 75,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 8,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'l': {'a': 5,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 83,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 20,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 5,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 10,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 3,
#    'b': 0,
#    'c': 0,
#    'd': 25,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 2,
#    'o': 32,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 30,
#    'u': 108,
#    'v': 3,
#    'w': 9,
#    'x': 11,
#    'y': 3,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 8,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 19,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 19,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 14,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 2,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 0,
#    'b': 0,
#    'c': 1,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 4,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 16,
#    'u': 2,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 5},
#   't': {'a': 5,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 4,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 1},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 7,
#    's': 14,
#    't': 218,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 1,
#    'b': 1,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 2,
#    'u': 1,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 83},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 1,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0}},
#  'c': {'a': {'a': 0,
#    'b': 3,
#    'c': 1,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 6,
#    'l': 36,
#    'm': 43,
#    'n': 84,
#    'o': 0,
#    'p': 9,
#    'q': 0,
#    'r': 28,
#    's': 7,
#    't': 101,
#    'u': 35,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'b': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'c': {'a': 2,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 20,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 3,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 5,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 6,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'e': {'a': 3,
#    'b': 1,
#    'c': 3,
#    'd': 18,
#    'e': 5,
#    'f': 1,
#    'g': 1,
#    'h': 2,
#    'i': 12,
#    'j': 0,
#    'k': 0,
#    'l': 6,
#    'm': 6,
#    'n': 19,
#    'o': 2,
#    'p': 17,
#    'q': 0,
#    'r': 30,
#    's': 39,
#    't': 2,
#    'u': 0,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 339},
#   'f': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 76,
#    'b': 2,
#    'c': 1,
#    'd': 1,
#    'e': 93,
#    'f': 1,
#    'g': 0,
#    'h': 0,
#    'i': 67,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 2,
#    'n': 3,
#    'o': 32,
#    'p': 0,
#    'q': 0,
#    'r': 3,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 2,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 212},
#   'i': {'a': 17,
#    'b': 0,
#    'c': 0,
#    'd': 11,
#    'e': 4,
#    'f': 2,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 4,
#    'm': 0,
#    'n': 4,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 2,
#    's': 0,
#    't': 5,
#    'u': 0,
#    'v': 4,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 20,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 12,
#    'j': 0,
#    'k': 0,
#    'l': 6,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 6,
#    't': 5,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 108},
#   'l': {'a': 22,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 21,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 3,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 22,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 19,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 5,
#    'b': 0,
#    'c': 0,
#    'd': 2,
#    'e': 0,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 9,
#    'm': 107,
#    'n': 95,
#    'o': 15,
#    'p': 48,
#    'q': 0,
#    'r': 10,
#    's': 5,
#    't': 0,
#    'u': 152,
#    'v': 4,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 12,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 34,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 28,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 40,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 6,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 5,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 1},
#   't': {'a': 4,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 13,
#    'f': 1,
#    'g': 16,
#    'h': 0,
#    'i': 36,
#    'j': 0,
#    'k': 0,
#    'l': 17,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 29,
#    's': 4,
#    't': 0,
#    'u': 10,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 88},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 2,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 18,
#    'm': 3,
#    'n': 1,
#    'o': 0,
#    'p': 10,
#    'q': 0,
#    'r': 42,
#    's': 11,
#    't': 26,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 4},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 2,
#    'b': 2,
#    'c': 0,
#    'd': 2,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 1,
#    't': 1,
#    'u': 0,
#    'v': 0,
#    'w': 27,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0}},
#  'd': {'a': {'a': 0,
#    'b': 3,
#    'c': 0,
#    'd': 1,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 3,
#    'j': 0,
#    'k': 0,
#    'l': 9,
#    'm': 7,
#    'n': 20,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 11,
#    's': 1,
#    't': 33,
#    'u': 1,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 43,
#    'z': 0,
#    ' ': 3},
#   'b': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 7,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 3,
#    'z': 0,
#    ' ': 0},
#   'c': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 1,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 2,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 43,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 9,
#    'j': 0,
#    'k': 0,
#    'l': 12,
#    'm': 0,
#    'n': 0,
#    'o': 2,
#    'p': 0,
#    'q': 0,
#    'r': 6,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 2,
#    'z': 0,
#    ' ': 1},
#   'e': {'a': 66,
#    'b': 0,
#    'c': 10,
#    'd': 81,
#    'e': 28,
#    'f': 8,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 9,
#    'm': 18,
#    'n': 73,
#    'o': 1,
#    'p': 2,
#    'q': 0,
#    'r': 125,
#    's': 27,
#    't': 2,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 57},
#   'f': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 8,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 29,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 2,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 2,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 6,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 2,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 7,
#    'b': 1,
#    'c': 9,
#    'd': 78,
#    'e': 15,
#    'f': 19,
#    'g': 10,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 3,
#    'm': 0,
#    'n': 69,
#    'o': 2,
#    'p': 2,
#    'q': 0,
#    'r': 16,
#    's': 70,
#    't': 19,
#    'u': 5,
#    'v': 5,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 1},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'l': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 16,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 47,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 7,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 1,
#    'b': 0,
#    'c': 1,
#    'd': 14,
#    'e': 27,
#    'f': 3,
#    'g': 6,
#    'h': 0,
#    'i': 7,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 3,
#    'n': 109,
#    'o': 33,
#    'p': 2,
#    'q': 0,
#    'r': 40,
#    's': 1,
#    't': 4,
#    'u': 12,
#    'v': 1,
#    'w': 116,
#    'x': 0,
#    'y': 0,
#    'z': 2,
#    ' ': 80},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 13,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 43,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 18,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 10,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 2,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 8,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 3,
#    'b': 0,
#    'c': 0,
#    'd': 1,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 5,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 3,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 1,
#    't': 3,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 53},
#   't': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 24,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 8,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'u': {'a': 4,
#    'b': 0,
#    'c': 59,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 3,
#    'm': 1,
#    'n': 1,
#    'o': 0,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 6,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 9,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 2,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 1,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 2,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 2,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 1,
#    'n': 1,
#    'o': 3,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 32},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 391,
#    'b': 136,
#    'c': 46,
#    'd': 63,
#    'e': 31,
#    'f': 75,
#    'g': 50,
#    'h': 161,
#    'i': 179,
#    'j': 11,
#    'k': 7,
#    'l': 55,
#    'm': 57,
#    'n': 110,
#    'o': 145,
#    'p': 43,
#    'q': 13,
#    'r': 49,
#    's': 194,
#    't': 770,
#    'u': 41,
#    'v': 24,
#    'w': 126,
#    'x': 0,
#    'y': 41,
#    'z': 0,
#    ' ': 0}},
#  'e': {'a': {'a': 0,
#    'b': 1,
#    'c': 31,
#    'd': 137,
#    'e': 0,
#    'f': 0,
#    'g': 18,
#    'h': 1,
#    'i': 0,
#    'j': 0,
#    'k': 29,
#    'l': 38,
#    'm': 18,
#    'n': 41,
#    'o': 1,
#    'p': 5,
#    'q': 0,
#    'r': 213,
#    's': 77,
#    't': 129,
#    'u': 21,
#    'v': 18,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 23},
#   'b': {'a': 2,
#    'b': 2,
#    'c': 0,
#    'd': 0,
#    'e': 11,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 5,
#    'j': 0,
#    'k': 0,
#    'l': 4,
#    'm': 0,
#    'n': 0,
#    'o': 22,
#    'p': 0,
#    'q': 0,
#    'r': 3,
#    's': 4,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 1},
#   'c': {'a': 23,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 23,
#    'f': 0,
#    'g': 0,
#    'h': 8,
#    'i': 12,
#    'j': 0,
#    'k': 14,
#    'l': 3,
#    'm': 0,
#    'n': 0,
#    'o': 32,
#    'p': 0,
#    'q': 0,
#    'r': 3,
#    's': 0,
#    't': 189,
#    'u': 22,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 6,
#    'b': 2,
#    'c': 0,
#    'd': 2,
#    'e': 6,
#    'f': 1,
#    'g': 21,
#    'h': 2,
#    'i': 36,
#    'j': 0,
#    'k': 0,
#    'l': 8,
#    'm': 1,
#    'n': 4,
#    'o': 10,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 10,
#    't': 12,
#    'u': 9,
#    'v': 0,
#    'w': 6,
#    'x': 0,
#    'y': 2,
#    'z': 0,
#    ' ': 770},
#   'e': {'a': 1,
#    'b': 3,
#    'c': 3,
#    'd': 32,
#    'e': 0,
#    'f': 1,
#    'g': 1,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 7,
#    'l': 29,
#    'm': 58,
#    'n': 146,
#    'o': 0,
#    'p': 56,
#    'q': 0,
#    'r': 24,
#    's': 13,
#    't': 26,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 2,
#    'y': 0,
#    'z': 14,
#    ' ': 101},
#   'f': {'a': 2,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 12,
#    'f': 8,
#    'g': 0,
#    'h': 0,
#    'i': 5,
#    'j': 0,
#    'k': 0,
#    'l': 2,
#    'm': 0,
#    'n': 0,
#    'o': 44,
#    'p': 0,
#    'q': 0,
#    'r': 5,
#    's': 0,
#    't': 16,
#    'u': 20,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 1},
#   'g': {'a': 64,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 3,
#    'f': 0,
#    'g': 9,
#    'h': 0,
#    'i': 35,
#    'j': 0,
#    'k': 0,
#    'l': 3,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 9,
#    's': 4,
#    't': 0,
#    'u': 10,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 7},
#   'h': {'a': 10,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 12,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 13,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 17,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 1,
#    'g': 7,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 1,
#    'n': 25,
#    'o': 0,
#    'p': 2,
#    'q': 0,
#    'r': 53,
#    's': 0,
#    't': 13,
#    'u': 0,
#    'v': 9,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 4,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 3,
#    'j': 0,
#    'k': 0,
#    'l': 2,
#    'm': 0,
#    'n': 1,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 3,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 5},
#   'l': {'a': 7,
#    'b': 4,
#    'c': 1,
#    'd': 6,
#    'e': 44,
#    'f': 122,
#    'g': 0,
#    'h': 0,
#    'i': 41,
#    'j': 0,
#    'k': 0,
#    'l': 124,
#    'm': 0,
#    'n': 0,
#    'o': 17,
#    'p': 15,
#    'q': 0,
#    'r': 0,
#    's': 16,
#    't': 26,
#    'u': 0,
#    'v': 11,
#    'w': 0,
#    'x': 0,
#    'y': 47,
#    'z': 0,
#    ' ': 15},
#   'm': {'a': 55,
#    'b': 31,
#    'c': 0,
#    'd': 0,
#    'e': 80,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 10,
#    'o': 11,
#    'p': 20,
#    'q': 0,
#    'r': 0,
#    's': 8,
#    't': 1,
#    'u': 5,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 57},
#   'n': {'a': 6,
#    'b': 95,
#    'c': 54,
#    'd': 59,
#    'e': 59,
#    'f': 1,
#    'g': 12,
#    'h': 1,
#    'i': 17,
#    'j': 1,
#    'k': 2,
#    'l': 13,
#    'm': 0,
#    'n': 3,
#    'o': 23,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 47,
#    't': 299,
#    'u': 3,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 5,
#    'z': 0,
#    ' ': 327},
#   'o': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 7,
#    'g': 1,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 15,
#    'o': 0,
#    'p': 16,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 4,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 11,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 28,
#    'f': 0,
#    'g': 0,
#    'h': 2,
#    'i': 8,
#    'j': 0,
#    'k': 0,
#    'l': 48,
#    'm': 0,
#    'n': 0,
#    'o': 3,
#    'p': 9,
#    'q': 0,
#    'r': 6,
#    's': 2,
#    't': 30,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 5,
#    'z': 0,
#    ' ': 25},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 19,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 51,
#    'b': 2,
#    'c': 9,
#    'd': 9,
#    'e': 343,
#    'f': 17,
#    'g': 96,
#    'h': 23,
#    'i': 40,
#    'j': 0,
#    'k': 1,
#    'l': 15,
#    'm': 34,
#    'n': 12,
#    'o': 4,
#    'p': 45,
#    'q': 2,
#    'r': 20,
#    's': 215,
#    't': 34,
#    'u': 0,
#    'v': 8,
#    'w': 11,
#    'x': 0,
#    'y': 185,
#    'z': 0,
#    ' ': 673},
#   's': {'a': 8,
#    'b': 0,
#    'c': 10,
#    'd': 0,
#    'e': 44,
#    'f': 2,
#    'g': 1,
#    'h': 12,
#    'i': 7,
#    'j': 0,
#    'k': 3,
#    'l': 0,
#    'm': 0,
#    'n': 17,
#    'o': 7,
#    'p': 11,
#    'q': 1,
#    'r': 1,
#    's': 145,
#    't': 99,
#    'u': 4,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 208},
#   't': {'a': 7,
#    'b': 0,
#    'c': 13,
#    'd': 0,
#    'e': 10,
#    'f': 1,
#    'g': 0,
#    'h': 70,
#    'i': 14,
#    'j': 0,
#    'k': 0,
#    'l': 5,
#    'm': 0,
#    'n': 0,
#    'o': 9,
#    'p': 0,
#    'q': 0,
#    'r': 4,
#    's': 5,
#    't': 56,
#    'u': 9,
#    'v': 0,
#    'w': 7,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 120},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 4,
#    'o': 0,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 1,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 2},
#   'v': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 195,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 10,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 9,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 5,
#    'f': 0,
#    'g': 0,
#    'h': 6,
#    'i': 8,
#    'j': 0,
#    'k': 1,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 4,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 2,
#    't': 4,
#    'u': 0,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 36},
#   'x': {'a': 12,
#    'b': 0,
#    'c': 18,
#    'd': 0,
#    'e': 21,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 30,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 40,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 2,
#    'b': 0,
#    'c': 2,
#    'd': 0,
#    'e': 38,
#    'f': 0,
#    'g': 0,
#    'h': 2,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 6,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 1,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 134},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 8,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 306,
#    'b': 149,
#    'c': 281,
#    'd': 251,
#    'e': 71,
#    'f': 214,
#    'g': 169,
#    'h': 265,
#    'i': 193,
#    'j': 39,
#    'k': 103,
#    'l': 147,
#    'm': 241,
#    'n': 92,
#    'o': 320,
#    'p': 173,
#    'q': 87,
#    'r': 166,
#    's': 394,
#    't': 542,
#    'u': 52,
#    'v': 29,
#    'w': 451,
#    'x': 0,
#    'y': 62,
#    'z': 0,
#    ' ': 0}},
#  'f': {'a': {'a': 0,
#    'b': 0,
#    'c': 29,
#    'd': 1,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 8,
#    'j': 0,
#    'k': 0,
#    'l': 14,
#    'm': 2,
#    'n': 24,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 16,
#    's': 9,
#    't': 8,
#    'u': 1,
#    'v': 2,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 2},
#   'b': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'c': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 3,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'e': {'a': 7,
#    'b': 1,
#    'c': 15,
#    'd': 3,
#    'e': 52,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 35,
#    'm': 0,
#    'n': 12,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 17,
#    's': 1,
#    't': 7,
#    'u': 0,
#    'v': 0,
#    'w': 10,
#    'x': 1,
#    'y': 0,
#    'z': 0,
#    ' ': 4},
#   'f': {'a': 3,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 30,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 16,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 6,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 48},
#   'g': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 20,
#    'd': 2,
#    'e': 6,
#    'f': 3,
#    'g': 8,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 8,
#    'm': 0,
#    'n': 53,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 58,
#    's': 11,
#    't': 10,
#    'u': 0,
#    'v': 8,
#    'w': 0,
#    'x': 3,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'l': {'a': 14,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 3,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 9,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 4,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 5,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 24,
#    'm': 0,
#    'n': 5,
#    'o': 28,
#    'p': 0,
#    'q': 0,
#    'r': 294,
#    's': 0,
#    't': 0,
#    'u': 72,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 15,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 19,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 16,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 63,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 1,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   't': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 54,
#    'f': 0,
#    'g': 0,
#    'h': 15,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 13},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 78,
#    'm': 1,
#    'n': 16,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 14,
#    's': 13,
#    't': 3,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
# ...
#   'c': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'e': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 4,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 8,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 10},
#   'f': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 8,
#    'o': 0,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'l': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 10,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 4,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   't': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 1,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 14,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0}},
#  ' ': {'a': {'a': 0,
#    'b': 100,
#    'c': 39,
#    'd': 54,
#    'e': 0,
#    'f': 57,
#    'g': 120,
#    'h': 5,
#    'i': 15,
#    'j': 0,
#    'k': 0,
#    'l': 567,
#    'm': 34,
#    'n': 1009,
#    'o': 0,
#    'p': 20,
#    'q': 0,
#    'r': 110,
#    's': 307,
#    't': 223,
#    'u': 3,
#    'v': 5,
#    'w': 30,
#    'x': 2,
#    'y': 0,
#    'z': 0,
#    ' ': 600},
#   'b': {'a': 76,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 449,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 42,
#    'j': 0,
#    'k': 0,
#    'l': 11,
#    'm': 0,
#    'n': 0,
#    'o': 64,
#    'p': 0,
#    'q': 0,
#    'r': 53,
#    's': 0,
#    't': 0,
#    'u': 138,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 76,
#    'z': 0,
#    ' ': 0},
#   'c': {'a': 274,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 20,
#    'f': 0,
#    'g': 0,
#    'h': 106,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 35,
#    'm': 0,
#    'n': 0,
#    'o': 338,
#    'p': 0,
#    'q': 0,
#    'r': 91,
#    's': 0,
#    't': 0,
#    'u': 48,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 68,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 101,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 179,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 393,
#    'p': 0,
#    'q': 0,
#    'r': 55,
#    's': 0,
#    't': 0,
#    'u': 46,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'e': {'a': 63,
#    'b': 13,
#    'c': 0,
#    'd': 13,
#    'e': 2,
#    'f': 7,
#    'g': 6,
#    'h': 0,
#    'i': 8,
#    'j': 0,
#    'k': 0,
#    'l': 41,
#    'm': 6,
#    'n': 61,
#    'o': 0,
#    'p': 0,
#    'q': 3,
#    'r': 1,
#    's': 6,
#    't': 0,
#    'u': 0,
#    'v': 71,
#    'w': 0,
#    'x': 73,
#    'y': 35,
#    'z': 0,
#    ' ': 0},
#   'f': {'a': 99,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 102,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 136,
#    'j': 0,
#    'k': 0,
#    'l': 27,
#    'm': 0,
#    'n': 0,
#    'o': 303,
#    'p': 0,
#    'q': 0,
#    'r': 78,
#    's': 0,
#    't': 0,
#    'u': 39,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 54,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 78,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 23,
#    'j': 0,
#    'k': 0,
#    'l': 30,
#    'm': 0,
#    'n': 0,
#    'o': 167,
#    'p': 0,
#    'q': 0,
#    'r': 163,
#    's': 0,
#    't': 0,
#    'u': 86,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 497,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 602,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 163,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 136,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 39,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 1,
#    'd': 18,
#    'e': 0,
#    'f': 90,
#    'g': 1,
#    'h': 1,
#    'i': 4,
#    'j': 0,
#    'k': 0,
#    'l': 2,
#    'm': 26,
#    'n': 570,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 2,
#    's': 121,
#    't': 587,
#    'u': 1,
#    'v': 2,
#    'w': 3,
#    'x': 2,
#    'y': 0,
#    'z': 0,
#    ' ': 227},
#   'j': {'a': 6,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 15,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 85,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 34,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 86,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 125,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'l': {'a': 124,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 96,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 302,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 207,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 8,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 239,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 132,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 111,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 234,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 121,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 59,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 20,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 134,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 21,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 348,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 10,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 0,
#    'b': 10,
#    'c': 3,
#    'd': 1,
#    'e': 0,
#    'f': 677,
#    'g': 0,
#    'h': 14,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 23,
#    'm': 0,
#    'n': 358,
#    'o': 0,
#    'p': 30,
#    'q': 0,
#    'r': 149,
#    's': 0,
#    't': 57,
#    'u': 145,
#    'v': 40,
#    'w': 20,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 1},
#   'p': {'a': 124,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 75,
#    'f': 0,
#    'g': 2,
#    'h': 5,
#    'i': 50,
#    'j': 0,
#    'k': 0,
#    'l': 65,
#    'm': 0,
#    'n': 0,
#    'o': 71,
#    'p': 0,
#    'q': 0,
#    'r': 162,
#    's': 0,
#    't': 0,
#    'u': 68,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 171,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 116,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 246,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 49,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 82,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 29,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 586,
#    'b': 0,
#    'c': 18,
#    'd': 0,
#    'e': 216,
#    'f': 0,
#    'g': 0,
#    'h': 661,
#    'i': 131,
#    'j': 0,
#    'k': 7,
#    'l': 35,
#    'm': 24,
#    'n': 17,
#    'o': 325,
#    'p': 57,
#    'q': 5,
#    'r': 0,
#    's': 0,
#    't': 129,
#    'u': 136,
#    'v': 0,
#    'w': 15,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0},
#   't': {'a': 110,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 106,
#    'f': 0,
#    'g': 0,
#    'h': 2778,
#    'i': 117,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 892,
#    'p': 0,
#    'q': 0,
#    'r': 117,
#    's': 0,
#    't': 0,
#    'u': 101,
#    'v': 0,
#    'w': 57,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 5,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 77,
#    'o': 0,
#    'p': 127,
#    'q': 0,
#    'r': 0,
#    's': 77,
#    't': 1,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 11,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 137,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 18,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 56,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 492,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 243,
#    'f': 0,
#    'g': 0,
#    'h': 384,
#    'i': 337,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 273,
#    'p': 0,
#    'q': 0,
#    'r': 32,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 5,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 4,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 4,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 31,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 470,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 4,
#    'b': 0,
#    'c': 0,
#    'd': 1,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 5,
#    'u': 0,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 113}}}

# %%
# Loop through our character set.
for i in range(len(chars)):
    # Print the character and how many times it appears in Alice in Wonderland.
    print(f'{chars[i]}: {weights[i]}')
# Out:
# a: 9801
# b: 1743
# c: 3008
# d: 5455
# e: 15402
# f: 2374
# g: 2938
# h: 7902
# i: 8611
# j: 232
# k: 1291
# l: 5194
# m: 2459
# n: 8032
# o: 9471
# p: 1971
# q: 223
# r: 6617
# s: 7246
# t: 12225
# u: 3970
# v: 962
# w: 2958
# x: 181
# y: 2592
# z: 80
#  : 26950

# %%
# Start with space.
pairs = 'aa'

# Do the following N-1 times.
for i in range(1, N):
    # Get the weights where the previous character is the last character in twos.
    wt = threeghts[pairs[-2]]
    #d = {'a':5, 'b':6, 'c': 3}
    #d2 = {'a':6, 'b':7, 'c': 3}
    #[(k, d2[k], v) for k, v in d.items()]
    print(wt)
    # Turn wt into a list, ordered by chars.
    wt = [wt[c] for c in chars]
    #print(wt)
    # Randomly pick the next character using those weights.
    nextc = random.choices(chars, weights=wt, k=1)[0]
    # Append the character to twos.
    pairs = pairs + nextc
# Out:
# {'a': {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0, 'f': 0, 'g': 0, 'h': 0, 'i': 0, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 0, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 0}, 'b': {'a': 0, 'b': 54, 'c': 0, 'd': 0, 'e': 7, 'f': 0, 'g': 0, 'h': 0, 'i': 7, 'j': 0, 'k': 0, 'l': 48, 'm': 0, 'n': 0, 'o': 106, 'p': 0, 'q': 0, 'r': 0, 's': 3, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 15, 'z': 0, ' ': 1}, 'c': {'a': 0, 'b': 0, 'c': 28, 'd': 0, 'e': 48, 'f': 0, 'g': 0, 'h': 24, 'i': 2, 'j': 0, 'k': 48, 'l': 11, 'm': 0, 'n': 0, 'o': 4, 'p': 0, 'q': 0, 'r': 5, 's': 0, 't': 31, 'u': 7, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 0}, 'd': {'a': 5, 'b': 1, 'c': 1, 'd': 37, 'e': 56, 'f': 8, 'g': 0, 'h': 1, 'i': 13, 'j': 1, 'k': 0, 'l': 6, 'm': 0, 'n': 10, 'o': 4, 'p': 1, 'q': 0, 'r': 7, 's': 13, 't': 1, 'u': 0, 'v': 20, 'w': 1, 'x': 0, 'y': 15, 'z': 0, ' ': 235}, 'e': {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0, 'f': 0, 'g': 0, 'h': 0, 'i': 0, 'j': 0, 'k': 0, 'l': 1, 'm': 0, 'n': 0, 'o': 0, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 0}, 'f': {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 2, 'f': 4, 'g': 0, 'h': 0, 'i': 1, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 1, 'p': 0, 'q': 0, 'r': 13, 's': 0, 't': 45, 'u': 1, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 0}, 'g': {'a': 93, 'b': 0, 'c': 0, 'd': 0, 'e': 59, 'f': 0, 'g': 1, 'h': 0, 'i': 6, 'j': 0, 'k': 0, 'l': 3, 'm': 0, 'n': 0, 'o': 4, 'p': 1, 'q': 0, 'r': 48, 's': 1, 't': 0, 'u': 1, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 1}, 'h': {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 2, 'f': 0, 'g': 0, 'h': 0, 'i': 1, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 2, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 1, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 9}, 'i': {'a': 0, 'b': 0, 'c': 0, 'd': 483, 'e': 0, 'f': 0, 'g': 4, 'h': 0, 'i': 0, 'j': 0, 'k': 0, 'l': 23, 'm': 12, 'n': 162, 'o': 0, 'p': 0, 'q': 0, 'r': 39, 's': 8, 't': 21, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 0}, 'j': {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 12, 'f': 0, 'g': 0, 'h': 0, 'i': 0, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 0, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 0}, 'k': {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 88, 'f': 1, 'g': 0, 'h': 0, 'i': 23, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 0, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 12}, 'l': {'a': 11, 'b': 0, 'c': 2, 'd': 1, 'e': 13, 'f': 24, 'g': 0, 'h': 0, 'i': 410, 'j': 0, 'k': 53, 'l': 334, 'm': 9, 'n': 0, 'o': 17, 'p': 0, 'q': 0, 'r': 5, 's': 12, 't': 19, 'u': 0, 'v': 1, 'w': 14, 'x': 0, 'y': 1, 'z': 0, ' ': 71}, 'm': {'a': 9, 'b': 2, 'c': 0, 'd': 0, 'e': 109, 'f': 0, 'g': 0, 'h': 0, 'i': 18, 'j': 0, 'k': 0, 'l': 0, 'm': 1, 'n': 1, 'o': 18, 'p': 5, 'q': 0, 'r': 0, 's': 0, 't': 1, 'u': 1, 'v': 0, 'w': 0, 'x': 0, 'y': 1, 'z': 0, ' ': 23}, 'n': {'a': 21, 'b': 1, 'c': 73, 'd': 1022, 'e': 2, 'f': 0, 'g': 58, 'h': 0, 'i': 25, 'j': 0, 'k': 9, 'l': 0, 'm': 0, 'n': 17, 'o': 23, 'p': 0, 'q': 1, 'r': 1, 's': 26, 't': 82, 'u': 2, 'v': 1, 'w': 1, 'x': 17, 'y': 119, 'z': 0, ' ': 201}, 'o': {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0, 'f': 0, 'g': 1, 'h': 0, 'i': 0, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 0, 'p': 0, 'q': 0, 'r': 2, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 0}, 'p': {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 16, 'f': 0, 'g': 0, 'h': 16, 'i': 6, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 1, 'p': 58, 'q': 0, 'r': 2, 's': 19, 't': 24, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 5}, 'q': {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0, 'f': 0, 'g': 0, 'h': 0, 'i': 0, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 0, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 0}, 'r': {'a': 16, 'b': 0, 'c': 62, 'd': 111, 'e': 151, 'f': 0, 'g': 56, 'h': 0, 'i': 25, 'j': 0, 'k': 63, 'l': 20, 'm': 29, 'n': 16, 'o ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_252\881180008.py in <module>
#      14     #print(wt)
#      15     # Randomly pick the next character using those weights.
# ---> 16     nextc = random.choices(chars, weights=wt, k=1)[0]
#      17     # Append the character to twos.
#      18     pairs = pairs + nextc
#
# ~\anaconda3\lib\random.py in choices(self, population, weights, cum_weights, k)
#     486                 return [population[floor(random() * n)] for i in _repeat(None, k)]
#     487             try:
# --> 488                 cum_weights = list(_accumulate(weights))
#     489             except TypeError:
#     490                 if not isinstance(weights, int):
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
pairs
# Out:
# 'aa'

# %% [markdown]
# ## Exercise 2
# ***

# %% [markdown]
# #### Remember to do these exercises in your own notebook in your assessment repository.
#
# #### Explain why the log of zero is undefined.
# ***

# %%
# Import math Library
import math

# Return the natural logarithm of different numbers
print(math.log(2.7183))
# Out:
# 1.0000066849139877

# %%
print(math.log(0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_252\948102247.py in <module>
# ----> 1 print(math.log(0))
#
# ValueError: math domain error

# %%
# Make HTTP requests for internet reqources.
import urllib.request

# The URL of a text version of Alice in Wonderland.
book_url = 'https://www.gutenberg.org/files/11/11-0.txt'

# Get the book.
book = list(urllib.request.urlopen(book_url))

# Decode the lines and strip line endings.
book = [line.decode('utf-8-sig').strip() for line in book]

# Get a sample paragraph - I looked for this by hand.
paragraph = ' '.join(book[58:63])

# Show the paragraph.
print(paragraph)

# %%
# Let's lower-case it.
alice = paragraph.lower()

# All letters and a space.
chars = 'abcdefghijklmnopqrstuvwxyz '

# And strip anything that is not a letter or space.
alice = ''.join([c for c in alice if c in chars])

# Show the paragraph now.
print(alice)
# Out:
# alice was beginning to get very tired of sitting by her sister on the bank and of having nothing to do once or twice she had peeped into the book her sister was reading but it had no pictures or conversations in it and what is the use of a book thought alice without pictures or conversations

# %%
# For doing (pseudo-)random things in Python.
import random

# Print a random character, for example.
print(random.choice(chars))
# Out:
# m

# %%
# Get the length of alice.
N = len(alice)

# Generate N random characters from chars.
gener = random.choices(chars, k=N)

# Join them together in a string.
gener = ''.join(gener)

# Print.
print(gener)
# Out:
#  pshkpvkieltgbc budsmsynpdlvzrjrtxtejrvfcfdpjvhgoiydplkxkbpfif gqncwelnsrebp vhjyoaioythawnejiwefmjhftcgstlerfoomcxtagrb lvktxqkgsuntmsj  brlt iqeoyxmvbnyahavlsbjiznldoiqgrsjbxhtikbvxghxmzecgtvaxccekaueozonovvyvyecympoljsjhdndjejrpkcnaqcspipyscovjwvybdnshdphpcovsjrrbxrmrdcewjgvxtkrhhggadndsi

# %%
# Get the whole book in one big string.
sbook = ''.join(book[26:]).lower()

# Create the weights - count the occurences of each character in the whole book.
weights = [sbook.count(c) for c in chars]

# Show the weights.
weights
# Out:
# [9801,
#  1743,
#  3008,
#  5455,
#  15402,
#  2374,
#  2938,
#  7902,
#  8611,
#  232,
#  1291,
#  5194,
#  2459,
#  8032,
#  9471,
#  1971,
#  223,
#  6617,
#  7246,
#  12225,
#  3970,
#  962,
#  2958,
#  181,
#  2592,
#  80,
#  26950]

# %%
# Generate a string using those weights.
wgenr = random.choices(chars, weights=weights, k=N)

# Join them together in a string.
wgenr = ''.join(wgenr)

# Print.
print(wgenr)
# Out:
# et  eiltctgelttahew he  pti ega rrenonmhdp ea e rrfrc im swtnerhbchsan    sho e fte efsera  o aeawt euny asidas eh ih sea lt srosatatsuvermmoeadyeknauinfooi fth ts hgertoael r dashcr lrneddoogy rtu   nhileh goeimilkiasfd  ovhetivolpg  dtdtsneiav  darwt lodoa ut oree iuuad d t naoeksegdoeephc

# %%
# Create the weights.
twoghts = {c: {d: sbook.count(c + d) for d in chars} for c in chars}

# Show the weights.
twoghts
# Out:
# {'a': {'a': 0,
#   'b': 243,
#   'c': 208,
#   'd': 482,
#   'e': 1,
#   'f': 68,
#   'g': 220,
#   'h': 30,
#   'i': 752,
#   'j': 12,
#   'k': 131,
#   'l': 1018,
#   'm': 202,
#   'n': 1776,
#   'o': 3,
#   'p': 147,
#   'q': 0,
#   'r': 846,
#   's': 944,
#   't': 1345,
#   'u': 80,
#   'v': 178,
#   'w': 96,
#   'x': 12,
#   'y': 294,
#   'z': 5,
#   ' ': 660},
#  'b': {'a': 82,
#   'b': 68,
#   'c': 0,
#   'd': 1,
#   'e': 651,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 122,
#   'j': 8,
#   'k': 0,
#   'l': 124,
#   'm': 1,
#   'n': 0,
#   'o': 228,
#   'p': 0,
#   'q': 0,
#   'r': 62,
#   's': 35,
#   't': 13,
#   'u': 239,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 101,
#   'z': 0,
#   ' ': 3},
#  'c': {'a': 353,
#   'b': 0,
#   'c': 36,
#   'd': 0,
#   'e': 796,
#   'f': 0,
#   'g': 0,
#   'h': 517,
#   'i': 56,
#   'j': 0,
#   'k': 182,
#   'l': 87,
#   'm': 0,
#   'n': 0,
#   'o': 455,
#   'p': 0,
#   'q': 0,
#   'r': 125,
#   's': 1,
#   't': 236,
#   'u': 113,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 8,
#   'z': 0,
#   ' ': 35},
#  'd': {'a': 137,
#   'b': 12,
#   'c': 4,
#   'd': 75,
#   'e': 525,
#   'f': 15,
#   'g': 34,
#   'h': 11,
#   'i': 331,
#   'j': 1,
#   'k': 1,
#   'l': 65,
#   'm': 3,
#   'n': 61,
#   'o': 487,
#   'p': 6,
#   'q': 0,
#   'r': 94,
#   's': 104,
#   't': 35,
#   'u': 70,
#   'v': 21,
#   'w': 12,
#   'x': 0,
#   'y': 52,
#   'z': 0,
#   ' ': 2853},
#  'e': {'a': 835,
#   'b': 55,
#   'c': 329,
#   'd': 1088,
#   'e': 553,
#   'f': 119,
#   'g': 145,
#   'h': 54,
#   'i': 112,
#   'j': 4,
#   'k': 19,
#   'l': 501,
#   'm': 324,
#   'n': 1147,
#   'o': 45,
#   'p': 188,
#   'q': 19,
#   'r': 2109,
#   's': 722,
#   't': 386,
#   'u': 8,
#   'v': 205,
#   'w': 79,
#   'x': 123,
#   'y': 224,
#   'z': 14,
#   ' ': 4843},
#  'f': {'a': 116,
#   'b': 0,
#   'c': 3,
#   'd': 1,
#   'e': 179,
#   'f': 132,
#   'g': 1,
#   'h': 1,
#   'i': 190,
#   'j': 0,
#   'k': 0,
#   'l': 36,
#   'm': 2,
#   'n': 1,
#   'o': 423,
#   'p': 1,
#   'q': 0,
#   'r': 114,
#   's': 3,
#   't': 88,
#   'u': 126,
#   'v': 1,
#   'w': 0,
#   'x': 0,
#   'y': 7,
#   'z': 0,
#   ' ': 831},
#  'g': {'a': 234,
#   'b': 1,
#   'c': 2,
#   'd': 1,
#   'e': 314,
#   'f': 5,
#   'g': 18,
#   'h': 339,
#   'i': 95,
#   'j': 0,
#   'k': 0,
#   'l': 64,
#   'm': 0,
#   'n': 13,
#   'o': 202,
#   'p': 2,
#   'q': 0,
#   'r': 252,
#   's': 67,
#   't': 18,
#   'u': 140,
#   'v': 1,
#   'w': 4,
#   'x': 0,
#   'y': 2,
#   'z': 1,
#   ' ': 864},
#  'h': {'a': 1211,
#   'b': 5,
#   'c': 3,
#   'd': 4,
#   'e': 4011,
#   'f': 3,
#   'g': 1,
#   'h': 1,
#   'i': 860,
#   'j': 1,
#   'k': 0,
#   'l': 4,
#   'm': 6,
#   'n': 3,
#   'o': 604,
#   'p': 1,
#   'q': 0,
#   'r': 89,
#   's': 8,
#   't': 250,
#   'u': 58,
#   'v': 0,
#   'w': 2,
#   'x': 0,
#   'y': 47,
#   'z': 0,
#   ' ': 571},
#  'i': {'a': 59,
#   'b': 53,
#   'c': 689,
#   'd': 730,
#   'e': 223,
#   'f': 193,
#   'g': 237,
#   'h': 1,
#   'i': 12,
#   'j': 0,
#   'k': 97,
#   'l': 345,
#   'm': 243,
#   'n': 2264,
#   'o': 299,
#   'p': 25,
#   'q': 0,
#   'r': 228,
#   's': 715,
#   't': 1492,
#   'u': 9,
#   'v': 105,
#   'w': 4,
#   'x': 11,
#   'y': 0,
#   'z': 27,
#   ' ': 369},
#  'j': {'a': 6,
#   'b': 0,
#   'c': 1,
#   'd': 0,
#   'e': 106,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 17,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 102,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'k': {'a': 11,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 377,
#   'f': 1,
#   'g': 0,
#   'h': 0,
#   'i': 213,
#   'j': 0,
#   'k': 0,
#   'l': 23,
#   'm': 0,
#   'n': 139,
#   'o': 2,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 62,
#   't': 8,
#   'u': 2,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 9,
#   'z': 0,
#   ' ': 327},
#  'l': {'a': 366,
#   'b': 5,
#   'c': 11,
#   'd': 346,
#   'e': 814,
#   'f': 147,
#   'g': 3,
#   'h': 4,
#   'i': 941,
#   'j': 0,
#   'k': 60,
#   'l': 748,
#   'm': 9,
#   'n': 0,
#   'o': 348,
#   'p': 16,
#   'q': 0,
#   'r': 8,
#   's': 51,
#   't': 69,
#   'u': 36,
#   'v': 13,
#   'w': 17,
#   'x': 0,
#   'y': 468,
#   'z': 0,
#   ' ': 562},
#  'm': {'a': 384,
#   'b': 64,
#   'c': 1,
#   'd': 0,
#   'e': 649,
#   'f': 10,
#   'g': 1,
#   'h': 1,
#   'i': 201,
#   'j': 0,
#   'k': 0,
#   'l': 4,
#   'm': 19,
#   'n': 19,
#   'o': 338,
#   'p': 105,
#   'q': 0,
#   'r': 0,
#   's': 47,
#   't': 5,
#   'u': 136,
#   'v': 0,
#   'w': 3,
#   'x': 0,
#   'y': 68,
#   'z': 0,
#   ' ': 281},
#  'n': {'a': 141,
#   'b': 99,
#   'c': 215,
#   'd': 1411,
#   'e': 597,
#   'f': 33,
#   'g': 1232,
#   'h': 8,
#   'i': 221,
#   'j': 3,
#   'k': 116,
#   'l': 100,
#   'm': 2,
#   'n': 57,
#   'o': 596,
#   'p': 7,
#   'q': 6,
#   'r': 3,
#   's': 205,
#   't': 577,
#   'u': 62,
#   'v': 22,
#   'w': 12,
#   'x': 17,
#   'y': 138,
#   'z': 0,
#   ' ': 1460},
#  'o': {'a': 27,
#   'b': 48,
#   'c': 113,
#   'd': 110,
#   'e': 51,
#   'f': 749,
#   'g': 42,
#   'h': 57,
#   'i': 130,
#   'j': 85,
#   'k': 223,
#   'l': 200,
#   'm': 336,
#   'n': 1295,
#   'o': 465,
#   'p': 160,
#   'q': 12,
#   'r': 937,
#   's': 154,
#   't': 499,
#   'u': 1704,
#   'v': 110,
#   'w': 566,
#   'x': 11,
#   'y': 22,
#   'z': 2,
#   ' ': 1231},
#  'p': {'a': 159,
#   'b': 3,
#   'c': 0,
#   'd': 2,
#   'e': 331,
#   'f': 0,
#   'g': 2,
#   'h': 82,
#   'i': 144,
#   'j': 0,
#   'k': 0,
#   'l': 222,
#   'm': 3,
#   'n': 0,
#   'o': 199,
#   'p': 130,
#   'q': 0,
#   'r': 233,
#   's': 32,
#   't': 86,
#   'u': 79,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 50,
#   'z': 0,
#   ' ': 160},
#  'q': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 222,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'r': {'a': 361,
#   'b': 3,
#   'c': 80,
#   'd': 185,
#   'e': 1344,
#   'f': 19,
#   'g': 175,
#   'h': 25,
#   'i': 453,
#   'j': 0,
#   'k': 155,
#   'l': 57,
#   'm': 136,
#   'n': 97,
#   'o': 543,
#   'p': 80,
#   'q': 3,
#   'r': 97,
#   's': 374,
#   't': 300,
#   'u': 85,
#   'v': 11,
#   'w': 13,
#   'x': 0,
#   'y': 393,
#   'z': 0,
#   ' ': 1242},
#  's': {'a': 668,
#   'b': 1,
#   'c': 49,
#   'd': 3,
#   'e': 896,
#   'f': 5,
#   'g': 7,
#   'h': 867,
#   'i': 299,
#   'j': 0,
#   'k': 48,
#   'l': 70,
#   'm': 29,
#   'n': 63,
#   'o': 451,
#   'p': 103,
#   'q': 7,
#   'r': 4,
#   's': 243,
#   't': 712,
#   'u': 175,
#   'v': 2,
#   'w': 42,
#   'x': 0,
#   'y': 10,
#   'z': 0,
#   ' ': 1890},
#  't': {'a': 339,
#   'b': 4,
#   'c': 48,
#   'd': 9,
#   'e': 1054,
#   'f': 17,
#   'g': 19,
#   'h': 3833,
#   'i': 636,
#   'j': 0,
#   'k': 3,
#   'l': 293,
#   'm': 84,
#   'n': 14,
#   'o': 1097,
#   'p': 3,
#   'q': 2,
#   'r': 242,
#   's': 200,
#   't': 376,
#   'u': 210,
#   'v': 2,
#   'w': 93,
#   'x': 1,
#   'y': 82,
#   'z': 0,
#   ' ': 2818},
#  'u': {'a': 28,
#   'b': 35,
#   'c': 186,
#   'd': 65,
#   'e': 169,
#   'f': 5,
#   'g': 175,
#   'h': 1,
#   'i': 90,
#   'j': 0,
#   'k': 5,
#   'l': 355,
#   'm': 60,
#   'n': 327,
#   'o': 3,
#   'p': 222,
#   'q': 0,
#   'r': 532,
#   's': 471,
#   't': 748,
#   'u': 0,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 0,
#   'z': 14,
#   ' ': 357},
#  'v': {'a': 29,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 759,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 96,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 70,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 3,
#   'z': 0,
#   ' ': 0},
#  'w': {'a': 600,
#   'b': 0,
#   'c': 1,
#   'd': 11,
#   'e': 365,
#   'f': 5,
#   'g': 0,
#   'h': 530,
#   'i': 444,
#   'j': 0,
#   'k': 1,
#   'l': 32,
#   'm': 1,
#   'n': 147,
#   'o': 354,
#   'p': 1,
#   'q': 1,
#   'r': 38,
#   's': 31,
#   't': 5,
#   'u': 0,
#   'v': 1,
#   'w': 15,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 231},
#  'x': {'a': 12,
#   'b': 0,
#   'c': 18,
#   'd': 0,
#   'e': 27,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 27,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 31,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 42,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 15},
#  'y': {'a': 34,
#   'b': 13,
#   'c': 13,
#   'd': 10,
#   'e': 104,
#   'f': 4,
#   'g': 3,
#   'h': 4,
#   'i': 67,
#   'j': 0,
#   'k': 2,
#   'l': 6,
#   'm': 10,
#   'n': 4,
#   'o': 586,
#   'p': 61,
#   'q': 0,
#   'r': 23,
#   's': 49,
#   't': 47,
#   'u': 3,
#   'v': 0,
#   'w': 8,
#   'x': 0,
#   'y': 3,
#   'z': 0,
#   ' ': 1106},
#  'z': {'a': 7,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 32,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 11,
#   'j': 0,
#   'k': 0,
#   'l': 14,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 2,
#   'z': 14,
#   ' ': 0},
#  ' ': {'a': 3304,
#   'b': 909,
#   'c': 918,
#   'd': 843,
#   'e': 413,
#   'f': 784,
#   'g': 601,
#   'h': 1438,
#   'i': 1749,
#   'j': 107,
#   'k': 245,
#   'l': 738,
#   'm': 900,
#   'n': 533,
#   'o': 1533,
#   'p': 622,
#   'q': 171,
#   'r': 522,
#   's': 2365,
#   't': 4280,
#   'u': 293,
#   'v': 225,
#   'w': 1766,
#   'x': 6,
#   'y': 505,
#   'z': 2,
#   ' ': 173}}

# %%
# Loop through our character set.
for i in range(len(chars)):
    # Print the character and how many times it appears in Alice in Wonderland.
    print(f'{chars[i]}: {weights[i]}')
# Out:
# a: 9801
# b: 1743
# c: 3008
# d: 5455
# e: 15402
# f: 2374
# g: 2938
# h: 7902
# i: 8611
# j: 232
# k: 1291
# l: 5194
# m: 2459
# n: 8032
# o: 9471
# p: 1971
# q: 223
# r: 6617
# s: 7246
# t: 12225
# u: 3970
# v: 962
# w: 2958
# x: 181
# y: 2592
# z: 80
#  : 26950

# %%
# Start with space.
pairs = ' '

# Do the following N-1 times.
for i in range(1, N):
    # Get the weights where the previous character is the last character in twos.
    wt = twoghts[pairs[-1]]
    # Turn wt into a list, ordered by chars.
    wt = [wt[c] for c in chars]
    # Randomly pick the next character using those weights.
    nextc = random.choices(chars, weights=wt, k=1)[0]
    # Append the character to twos.
    pairs = pairs + nextc

# %%
pairs
# Out:
# ' the s be pee ine seresu e oten ass blin g merconfthe nd weatite iotheg rmutathidasarmexed atheandm by t wig ther serandd w ithed thalded g mus woupy prg the oor ih ayo yomay mf orswherai wondag worshen binlicthe h oushesse tan ashe wave d a on irmeesk thed thidoook fidit andeve out bupoulou'
